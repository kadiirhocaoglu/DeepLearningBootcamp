# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('datasets/audi.csv')

# %%
data.head(6)
# Out:
#    index    Year       Type  Mileage(miles) Engine          PS Transmission  \
# 0      0  2018.0  Hatchback         44000.0   1.6L  114.398422       Manual
# 1      4  2016.0  Hatchback         42596.0   1.0L   93.688363       Manual
# 2      7  2015.0  Hatchback         42700.0   1.4L  123.274162       Manual
# 3     11  2014.0  Hatchback         86000.0   1.6L  103.550296       Manual
# 4     12  2014.0  Hatchback        104310.0   1.6L  103.550296       Manual
# 5     15  2015.0  Hatchback         55191.0   1.4L  123.274162       Manual
#
#      Fuel  Number_of_Owners  Price(£)  \
# 0  Diesel                 1   14995.0
# 1  Petrol                 3   10755.0
# 2  Petrol                 2   10799.0
# 3  Diesel                 3    7490.0
# 4  Diesel                 3    7400.0
# 5  Petrol                 2    9991.0
#
#                                                 href          PPY  \
# 0  https://www.autotrader.co.uk/car-details/20221...  2499.166667
# ...

# %%
pre_data = data.drop(columns = ["index","href","MileageRank","Type"	,"PriceRank",	"PPYRank",	"Score"])

# %%
pre_data.head()
# Out:
#      Year  Mileage(miles) Engine          PS Transmission    Fuel  \
# 0  2018.0         44000.0   1.6L  114.398422       Manual  Diesel
# 1  2016.0         42596.0   1.0L   93.688363       Manual  Petrol
# 2  2015.0         42700.0   1.4L  123.274162       Manual  Petrol
# 3  2014.0         86000.0   1.6L  103.550296       Manual  Diesel
# 4  2014.0        104310.0   1.6L  103.550296       Manual  Diesel
#
#    Number_of_Owners  Price(£)          PPY
# 0                 1   14995.0  2499.166667
# 1                 3   10755.0  2688.750000
# 2                 2   10799.0  3599.666667
# 3                 3    7490.0  3745.000000
# 4                 3    7400.0  3700.000000

# %%
pre_data.tail(5)
# Out:
#        Year  Mileage(miles) Engine          PS Transmission    Fuel  \
# 466  2014.0         40195.0   1.4L  138.067061    Automatic  Petrol
# 467  2020.0         26218.0   1.0L  114.398422       Manual  Petrol
# 468  2017.0         48571.0   1.4L  123.274162       Manual  Petrol
# 469  2020.0          9584.0   1.0L   93.688363       Manual  Petrol
# 470  2019.0         17303.0   1.0L  114.398422       Manual  Petrol
#
#      Number_of_Owners  Price(£)          PPY
# 466                 3   11275.0  5637.500000
# 467                 1   18495.0  2311.875000
# 468                 2   11995.0  2399.000000
# 469                 1   19970.0  2496.250000
# 470                 1   17195.0  2456.428571

# %%
pre_data['Engine'] = pre_data['Engine'].str.replace("L", "")

# %%
pre_data['Engine'] = pd.to_numeric(pre_data['Engine'])

# %%
pre_data.head()
# Out:
#      Year  Mileage(miles)  Engine          PS  Number_of_Owners  Price(£)  \
# 0  2018.0         44000.0     1.6  114.398422                 1   14995.0
# 1  2016.0         42596.0     1.0   93.688363                 3   10755.0
# 2  2015.0         42700.0     1.4  123.274162                 2   10799.0
# 3  2014.0         86000.0     1.6  103.550296                 3    7490.0
# 4  2014.0        104310.0     1.6  103.550296                 3    7400.0
#
#            PPY  Transmission_Automatic  Transmission_Manual  Fuel_Diesel  \
# 0  2499.166667                   False                 True         True
# 1  2688.750000                   False                 True        False
# 2  3599.666667                   False                 True        False
# 3  3745.000000                   False                 True         True
# 4  3700.000000                   False                 True         True
#
#    Fuel_Petrol
# 0        False
# 1         True
# 2         True
# ...
